# %% [markdown]
# <a href="https://colab.research.google.com/github/SayuriHR/funadamentos-4/blob/main/Fundamentos4_CyP_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 02/12/21

# %% [markdown]
# una funcion es una unidad de codigo reutilizable, ademas de ser un mecanismo para organizar codigo.
#
# La gran ventja de emplear funciones es simplificar la progracion.
#
# ### Estructura
# Una funcion puede tomar cualquier cantidad de parametros de entrada ( de cualquier tipo) y retornar unicamente un solo valor.
# Un parametro de entrada es un valor que resive la funcion pra realizar sus operaciones.
#
# Con una funcion se pueden hacer 2 cosas:
# 1. definirla
# 2. invocarla(ejecutarla)
#
# La gran ventaja de tener una funcion declarada es que la podemos reutilizar cuando desee.

# %% [markdown]
# #Modularidad (funciones)
# ![image.png](data:image/png;base64,...)

# %%
def sumar( op1,op2):
    res = op1 + op2 
    return res

# %%
res = sumar(2 , 5)
print(res)
res = sumar(33, 22 )
print(res)
# Out:
# 7
# 55

# %%
print("Hola","Sayuri",sep="-")
# Out:
# Hola-Sayuri

# %%
def salma( op1 , op2 ):
    res= op1 + op2
    return res
salma(1,2)
# Out:
# 3

# %%
def imprime_cuadro():
    print("****")
    print("****")
    print("****")
    print("****")
    #return None 
imprime_cuadro()
# Out:
# ****
# ****
# ****
# ****

# %% [markdown]
# # valor de retorno de una funcion
#
# regla de oro.- Una funcion siempre returna UN SOLO VALOR. Inclusive si el valor es el vacion

# %%
#i nvocar sumar
res=sumar(7,8)
print(res)
#invocarla funcion pintar cuadro 
res = imprime_cuadro()
print(res)
# Out:
# 15
# ****
# ****
# ****
# ****
# None

# %% [markdown]
# # La palabra reservada None de python
# Esta palabra reservada significa vacio, equivalente a la palabra reservada void del lenguaje C ,C++ y Java.
#
# Seu usa para indicar ya sea return vacio o que se recive como parametro un vacio

# %%
def multiplicar(valor , veces):
    c = valor * veces
    return c

# %%
res = multiplicar(5,5)
print(res)
# Out:
# 25

# %%
def multiplicar(valor , veces):
    if valor == None:
        c=-1
    else:
        c = valor * veces
    return c

# %%
res = multiplicar( None, 5 )
print(res)
# Out:
# -1

# %% [markdown]
# #parámetros y argumentos.
# Son conceptos relacionados y su diferencia esta centrada en el momento que se emplea en una funcion.
#
# Es decir en la funcion sumar de arriba cuando se declara se le llama parametro y cuando se invoca se le llama argumento.

# %% [markdown]
# # Argumentos posicionales
# En Python es posible determinar a que parametro estan dirigidos los argumentos segun du posición

# %%
def dividir(op1, op2):
    c = op1/op2
    return c

# %%
num1 = 25
num2 =5
res = dividir(num1 , num2)
print(res)
res = dividir(num2 , num1)
print(res)
# Out:
# 5.0
# 0.2

# %% [markdown]
# # Argumentos con palabras clave (keywords)
#
# Es la posibilidad de indicarle a la funcion en tiempo de ejecucion a que parametro va dirigido un argumento de entrada.
#
# Solo disponible en Python

# %%
res = dividir(op2=num2 , op1=num1)   #tienes que especificar con el op1 y op2 el orden 
print(res)
# Out:
# 5.0

# %%
def letra_L(caracter):
    print(f"   {caracter}")
    print(f"   {caracter}")
    print(f"   {caracter}")
    print(f"   {caracter}")
    print(f"   {caracter}{caracter}{caracter}{caracter}{caracter}")

# %%
letra_L('l')
# Out:
#    l
#    l
#    l
#    l
#    lllll

# %% [markdown]
# ## 07/12/21

# %% [markdown]
# # Argmento por defecto
#
# Es la capacidad de las funciones de establecer un valor de defecto. (Default)
#
# Si no envia un argumento a dicho parametro entonces se asigna el que el progrmador asigno como default

# %%
def dividir(op1, op2=2):
    c = op1/ op2
    return c

print(dividir(25) )
# Out:
# 12.5

# %% [markdown]
# Este concepto se puede ejemplificar con la funcion ** print**.

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
nombre = "Sayuri"
edad = 19
print(nombre,edad, sep=':)')  # el sep es el espacio y puedes poner cualquier valor 
print("hola", end=" ")
print("-----------")
# Out:
# Sayuri:)19
# hola -----------

# %% [markdown]
# #  ejercicio de argumentos posicionales

# %%
def comanda(comensal=1,primer="Consome", segundo= "Arroz rojo", tercero="Enchiladas"):
    print(f"El comensal {comensal} quiere:")
    print("\t entrada:", primer)
    print("\t medio:",segundo)
    print("\t plato fuerte:", tercero)

comanda()

comanda(3, "Ensalada", "Arroz blanco", "Esparragos al horno")
# Out:
# El comensal 1 quiere:
# 	 entrada: Consome
# 	 medio: Arroz rojo
# 	 plato fuerte: Enchiladas
# El comensal 3 quiere:
# 	 entrada: Ensalada
# 	 medio: Arroz blanco
# 	 plato fuerte: Esparragos al horno

# %% [markdown]
# # argumentos enviados en grupo en un tupla
# Esto sirve para enviar multiples argumentos a una funcion empleando el comodin *.
#
# ```
#
# def mifun(args*)
#     <cuerpo de la fune>
#
# ```

# %%
def comanda2( *opciones ):
    #print(opciones)
    print(f"El comensal {opciones[0]} pidio:")
    print("\tEntrada:", opciones[1])
    print("\tSegundo:", opciones[2])
    print("\tPlato fuerte:", opciones[3])
    print("indicaciones extra:")
    for instruccion in opciones[4::]:
        print(instruccion)

comanda2(1, "Sopa de fideo", "Arroz", "Arrachera", "La arracehra aun se mueva", "Postre gelatina")
# Out:
# El comensal 1 pidio:
# 	Entrada: Sopa de fideo
# 	Segundo: Arroz
# 	Plato fuerte: Arrachera
# indicaciones extra:
# La arracehra aun se mueva
# Postre gelatina

# %% [markdown]
# # Argumentos enviados en grupo en un diccionario
#
# Es el mismo concepto que el anterior pero se usa el comodin ** y se mapea a un diccionario.

# %%
def comanda3( **opciones ):
    print(opciones)
    print(f"El comensal {opciones['comensal']} pidio")
    
comanda3(segundo="arroz blanco",tercero="Esparragos al horno",primer="Ensalada",comensal=3)
# Out:
# {'segundo': 'arroz blanco', 'tercero': 'Esparragos al horno', 'primer': 'Ensalada', 'comensal': 3}
# El comensal 3 pidio

# %%
def comanda3( **opciones ):
    ops = opciones.keys()
    print(ops)
    for key in ops:
        print(f"{key} = {opciones[key]}")

comanda3(segundo="arroz blanco",tercero="Esparragos al horno",primer="Ensalada",comensal=3)
# Out:
# dict_keys(['segundo', 'tercero', 'primer', 'comensal'])
# segundo = arroz blanco
# tercero = Esparragos al horno
# primer = Ensalada
# comensal = 3

# %%
# modularidad y bibloteca 
todos los lenguajes de programcion tienen la capacidad de compartir 
codigo entre la comunidad de programdaores.

Para ello cada lenuaje establece un mecanismo para escribir
y compartir bliblotecas

# %%
# !pip install simple_chalk
# Out:
# ...
#   Created wheel for simple-chalk: filename=simple_chalk-0.1.0-py3-none-any.whl size=22163 sha256=0bf7e96325ea25cb960a8956baa9731f0b4d6420a3b7c1ab6b658ff14f0bcadc
#   Stored in directory: /root/.cache/pip/wheels/24/e2/84/d54838032016039eef79df1137b91defaa6db068d825dfcdcd
# Successfully built simple-chalk
# ...

# %%
from simple_chalk import chalk, yellow

print(chalk.yellow("Hola en color amarillo"))
# Out:
# Hola en color amarillo

# %% [markdown]
# # ¿Como escribo un modulo (biblioteca)?
#
# Se define en un archivo de biblioteca.

# %%
# !cat mi_modulo.py
# Out:
# def sumar(a, b):
#     return a + b
#
# def mi_print(texto, final):
#     print("Super:", text, end=final)

# %%
import mi_modulo
res=mi_modulo.sumar(7,5)
print(res)

mi_modulo.mi_print("Sayuri", "\n")
# Out:
# 12
# Super: Sayuri

# %%
from mi_modulo import sumar , mi_print 
res = sumar(5 ,3)
print( res )
mi_print("Sayuri", "\n")
# Out:
# 8
# Super: Sayuri

# %% [markdown]
# #maenjo de archivos con Phyton3
#
# - leer archivos
# - escribir en archivos
# - manipular la informacion leida desde un archivo
# - formato de archivo

# %%
archivo = open("salida.txt", "wt")
archivo.write("Hola mundo")
archivo.close()

# %%
# !cat salida.txt
# Out:
# Hola mundo
